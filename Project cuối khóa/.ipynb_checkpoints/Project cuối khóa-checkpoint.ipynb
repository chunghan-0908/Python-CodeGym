# %% [markdown]
# Quản lý nhân sự (mã nhân viên, họ, tên, năm sinh, giới tính, mã phòng ban, mã chức vụ), phòng ban (mã phòng ban, tên), chức vụ (mã chức vụ, tên).
# Các chức năng chính: thêm, sửa, xóa, tìm thông tin nhân sự.

# %%
class Employee:
    def __init__(self, IdEmployee, LastName, FirstName, Sex, IdDepartment, IdPosition):
        self.IdEmployee = IdEmployee
        self.LastName = LastName
        self.FirstName = FirstName
        self.Sex = Sex
        self.IdDepartment = IdDepartment
        self.IdPosition = IdPosition
    
    def __str__(self):
        return f"Mã nhân viên: {self.IdEmployee} Họ và tên: {self.LastName} {self.FirstName}"

# %%
#Form đăng nhập
from tkinter import *
from tkinter import messagebox

window = Tk()
window.title("ĐĂNG NHẬP HỆ THỐNG")
window.geometry("440x200") 
window.configure(bg="#CCFFFF")


Department_list = [{"IdDepartment": "DPT01", "Name": "Phòng nhân sự"},
                   {"IdDepartment": "DPT02", "Name": "Phòng kinh doanh"},
                   {"IdDepartment": "DPT03", "Name": "Phòng công nghệ thông tin"},
                   {"IdDepartment": "DPT01", "Name": "Phòng kế toán"}]

Position_List = [{"IdPosition": "PST01", "Name": "Giám đốc"},
                   {"IdDepartment": "PST02", "Name": "Phó giám đốc"},
                   {"IdDepartment": "PST03", "Name": "Tổ trưởng"},
                   {"IdDepartment": "PST04", "Name": "Nhân viên"}]

#Mở form quản lý
def open_management_form():
    management_w = Tk()
    management_w.title("CHƯƠNG TRÌNH QUẢN LÝ")
    management_w.geometry("600x300") 
    management_w.configure(bg="#CCFFFF")
    management_w.mainloop()
    
    Employee_list = []
    
    #Tạo các label
    lbl_title = Label(management_w, text="QUẢN LÝ THÔNG TIN NHÂN VIÊN ")
    lbl_IdEmp = Label(management_w, text="IdEmployee: ")
    lbl_LastName = Label(management_w, text="Last Name: ")
    lbl_FirstName = Label(management_w, text="First Name: ")
    lbl_Sex = Label(management_w, text="Sex: ")
    lbl_IdDept = Label(management_w, text="IdDepartment: ")
    lbl_IdPos = Label(management_w, text="IdPosition: ")
    
    #Tạo các entry
    IdEmp = Entry(management_w)
    LastName = Entry(management_w)
    FirstName = Entry(management_w)
    Sex = Entry(management_w)
    IdDept = Entry(management_w)
    IdPos = Entry(management_w)
    
    #Tạo các button
    btn_Add = Button(management_w, text="Add")
    btn_Update = Button(management_w, text="Update")
    btn_Delete = Button(management_w, text="Delete")
    btn_Search = Button(management_w, text="Search")
    
    #Gán tọa độ
    lbl_title.place(x=300, y=10)
    lbl_IdEmp.place(x=250, y=20)
    lbl_LastName.place(x=250, y=40)
    lbl_FirstName.place(x=250, y=60)
    lbl_Sex.place(x=250, y=80)
    lbl_IdDept.place(x=250, y=100)
    lbl_IdPos.place(x=250, y=120)
    
    IdEmp.place(x=270, y=20)
    LastName.place(x=270, y=40)
    FirstName.place(x=270, y=60)
    Sex.place(x=270, y=80)
    IdDept.place(x=270, y=100)
    IdPos.place(x=270, y=120)
    
    btn_Add.place(x=250, y=140)
    btn_Update.place(x=270, y=140)
    btn_Delete.place(x=290, y=140)
    btn_Search.place(x=310, y=140)
    
    management_w.mainloop()
    
    
#Tạo các label cho form đăng nhập
lbl_login = Label(window, text="ĐĂNG NHẬP HỆ THỐNG", font=("bold"),bg="#CCFFFF")
lbl_username = Label(window, text="Tên đăng nhập: ", bg="#CCFFFF")
lbl_password = Label(window, text="Mật khẩu: ", bg="#CCFFFF")

#Tạo các entry cho form đăng nhập
username = Entry(window)
password = Entry(window)

#Tạo các button cho form đăng nhập
btn_login = Button(window, text="ĐĂNG NHẬP", bg="#00FFFF",command=open_management_form)
btn_changepassword = Button(window, text="ĐỔI MẬT KHẨU", bg="#00FFFF")


#Gán tọa độ form đăng nhập
lbl_login.place(x=125, y =10)
lbl_username.place(x=100, y =40)
lbl_password.place(x=100, y =70)
username.place(x=200, y=40)
password.place(x=200, y=70)
btn_login.place(x=145, y=100)
btn_changepassword.place(x=230, y=100)
    
window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[30], line 64
#      57 btn_changepassword.place(x=230, y=100)
#      63 #Tạo các label
# ---> 64 lbl_title = Label(management_w, text="QUẢN LÝ THÔNG TIN NHÂN VIÊN ")
#      65 lbl_IdEmp = Label(management_w, text="IdEmployee: ")
#      66 lbl_LastName = Label(management_w, text="Last Name: ")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py:3214, in Label.__init__(self, master, cnf, **kw)
#    3196 def __init__(self, master=None, cnf={}, **kw):
#    3197     """Construct a label widget with the parent MASTER.
#    3198
#    3199     STANDARD OPTIONS
#    (...)
#    3212
#    3213     """
# -> 3214     Widget.__init__(self, master, 'label', cnf, kw)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py:2628, in BaseWidget.__init__(self, master, widgetName, cnf, kw, extra)
#    2626 for k, v in classes:
#    2627     del cnf[k]
# -> 2628 self.tk.call(
#    2629     (widgetName, self._w) + extra + self._options(cnf))
#    2630 for k, v in classes:
#    2631     k.configure(self, v)
#
# TclError: can't invoke "label" command: application has been destroyed
